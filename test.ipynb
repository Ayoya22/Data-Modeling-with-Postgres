# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(13, '1542012644796', 100, 'free', None, None, '428', 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (2, '1541990264796', 53, 'free', None, None, '438', 'Klamath Falls, OR', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"'),
#  (1, '1541990258796', 10, 'free', None, None, '345', 'Washington-Arlington-Alexandria, DC-VA-MD-WV', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"'),
#  (19, '1542017923796', 34, 'free', None, None, '318', 'Milwaukee-Waukesha-West Allis, WI', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (53, 'Celeste', 'Williams', 'F', 'free'),
#  (29, 'Jacqueline', 'Lynch', 'F', 'paid'),
#  (68, 'Jordan', 'Rodriguez', 'F', 'free'),
#  (94, 'Noah', 'Chavez', 'M', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, 207.77751),
#  ('SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 'ARB29H41187B98F0EF', 1972, 342.56934),
#  ('SOPSWQW12A6D4F8781', 'Made Like This (Live)', 'ARGIWFO1187B9B55B7', 0, 225.09669),
#  ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 'ARH4Z031187B9A71F2', 1961, 156.39465),
#  ('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, 269.58322)]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan', 'Morris Plains, NJ', 40.82624, -74.47995),
#  ('ARB29H41187B98F0EF', 'Terry Callier', 'Chicago', 41.88415, -87.63241),
#  ('ARGIWFO1187B9B55B7', 'Five Bolt Main', '', nan, nan),
#  ('ARH4Z031187B9A71F2', 'Faye Adams', 'Newark, NJ', 40.73197, -74.17418),
#  ('AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', 49.80388, 15.47491)]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(1970, 1, 1, 0, 25, 41, 990259), 0, 1, 1, 1, 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 990265), 0, 1, 1, 1, 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 990542), 0, 1, 1, 1, 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 990753), 0, 1, 1, 1, 1970, '3'),
#  (datetime.datetime(1970, 1, 1, 0, 25, 41, 990843), 0, 1, 1, 1, 1970, '3')]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %% [markdown]
# ## Verifying Number of records in the tables:

# %%
# %sql SELECT count(*) FROM songplays;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(96,)]

# %%
# %sql SELECT * FROM songplays where song_id!='None' 0R artist_id!='None';
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# (psycopg2.ProgrammingError) syntax error at or near "0"
# LINE 1: SELECT * FROM songplays where song_id!='None' 0R artist_id!=...
#                                                       ^
#  [SQL: "SELECT * FROM songplays where song_id!='None' 0R artist_id!='None';"]

# %%
# %sql SELECT count(distinct artist_id) FROM songs;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(69,)]

# %%
# %sql SELECT count(*) FROM users;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(96,)]

# %%
# %sql SELECT count(distinct artist_id) FROM artists;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(69,)]

# %%
# %sql SELECT count(*) FROM time;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(6813,)]

# %%
# %sql SELECT *  FROM songs;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, 207.77751),
#  ('SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 'ARB29H41187B98F0EF', 1972, 342.56934),
#  ('SOPSWQW12A6D4F8781', 'Made Like This (Live)', 'ARGIWFO1187B9B55B7', 0, 225.09669),
#  ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 'ARH4Z031187B9A71F2', 1961, 156.39465),
#  ('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, 269.58322),
#  ('SOGXHEG12AB018653E', 'It Makes No Difference Now', 'AR0RCMP1187FB3F427', 1992, 133.32853),
#  ('SOYTPEP12AB0180E7B', 'Twist and Shout', 'ARAJPHH1187FB5566A', 1964, 164.80608),
#  ('SOBLGCN12AB0183212', 'James (Hold The Ladder Steady)', 'AR47JEX1187B995D81', 1985, 124.86485),
#  ('SOBZBAZ12A6D4F8742', 'Spanish Grease', 'AROUOZZ1187B9ABE51', 1997, 168.25424),
#  ('SOOLYAZ12A6701F4A6', 'Laws Patrolling (Album Version)', 'AREBBGV1187FB523D2', 0, 173.66159),
# ...

# %%
# %sql SELECT * FROM artists;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 69 rows affected.
# [('ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan', 'Morris Plains, NJ', 40.82624, -74.47995),
#  ('ARB29H41187B98F0EF', 'Terry Callier', 'Chicago', 41.88415, -87.63241),
#  ('ARGIWFO1187B9B55B7', 'Five Bolt Main', '', nan, nan),
#  ('ARH4Z031187B9A71F2', 'Faye Adams', 'Newark, NJ', 40.73197, -74.17418),
#  ('AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', 49.80388, 15.47491),
#  ('AR0RCMP1187FB3F427', 'Billie Jo Spears', 'Beaumont, TX', 30.08615, -94.10158),
#  ('ARAJPHH1187FB5566A', 'The Shangri-Las', 'Queens, NY', 40.7038, -73.83168),
#  ('AR47JEX1187B995D81', 'SUE THOMPSON', 'Nevada, MO', 37.83721, -94.35868),
#  ('AROUOZZ1187B9ABE51', 'Willie Bobo', 'New York, NY [Spanish Harlem]', 40.79195, -73.94512),
#  ('AREBBGV1187FB523D2', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 'Houston, TX', nan, nan),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', nan, nan),
# ...

# %%
# %sql SELECT * FROM songplays LIMIT 50;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 50 rows affected.
# [(13, '1542012644796', 100, 'free', None, None, '428', 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (2, '1541990264796', 53, 'free', None, None, '438', 'Klamath Falls, OR', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"'),
#  (1, '1541990258796', 10, 'free', None, None, '345', 'Washington-Arlington-Alexandria, DC-VA-MD-WV', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"'),
#  (19, '1542017923796', 34, 'free', None, None, '318', 'Milwaukee-Waukesha-West Allis, WI', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
# ...
